# %%
import pandas as pd
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc

# %%
def predict_data(X_train, y_train, algo):
    algo.fit(X_train, y_train)
    prediction = algo.predict(X_train)

    print(classification_report(y_train, prediction))
    return prediction

def to_numBoolean(dataframe, column_list):
    
    for column in column_list:
        dataframe[column] = dataframe[column].astype(int)
    
    return dataframe

def clean_data(df1, df2, df3, df4, df5, df6):
    org_frame = pd.concat([df1, df2, df3, df4, df5, df6])
    dataframe = deepcopy(org_frame)
    dataframe.drop(columns=['Entry_point', 'Exit_point'], inplace=True)
    dataframe.reset_index(inplace=True, drop=True)
    return dataframe

# %% [markdown]
# # Scenario Batch

# %%
data_sc31 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch1_etk.csv")

data_sc32 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch2_LegranSE.csv")

data_sc33 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch3_Marshall.csv")

data_sc34 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch4_Roamer.csv")

data_sc35 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch5_Truck.csv")

data_sc36 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch6_Wagon.csv")

# %%
combined_dataframe = pd.concat([data_sc31, data_sc32, data_sc33, data_sc34, data_sc35, data_sc36])
# combined_dataframe_sc2 = pd.concat([data_21, data_22, data_23, data_24, data_25])
print(combined_dataframe.columns)
# Out:
# Index(['Unnamed: 0', 'bins_0_75', 'bins_1_75', 'bins_2_75', 'bins_3_75',
#        'bins_4_75', 'bins_5_75', 'bins_6_75', 'bins_7_75', 'Entry',
#        'Entry_point', 'Exit', 'Exit_point', 'path_label', 'outcome'],
#       dtype='object')

# %%
combined_dataframe = clean_data(combined_dataframe)
combined_dataframe
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0          5.0       80.0      100.0     2851.0       60.0        4.0
# 1        691.0       48.0       10.0       14.0       10.0        2.0
# 2          4.0        8.0       97.0     3191.0      126.0        6.0
# 3        856.0       42.0       12.0        8.0        8.0        1.0
# 4         15.0        8.0       51.0     3588.0      144.0        4.0
# ..         ...        ...        ...        ...        ...        ...
# 779     1574.0        7.0        2.0        5.0        3.0        0.0
# 780        1.0        2.0       74.0     7467.0      101.0        2.0
# 781     1303.0        8.0        3.0        4.0        3.0        1.0
# 782        1.0        3.0       77.0     7391.0       87.0        1.0
# 783     1639.0       10.0        2.0        4.0        2.0        0.0
#
#      bins_6_75  bins_7_75  Entry   Exit  outcome
# 0          1.0        2.0   True  False     True
# ...

# %% [markdown]
# # Scenario 4 Batch

# %%
data_sc41 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch1_etk.csv")

data_sc42 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch2_LegranSE.csv")

data_sc43 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch3_Marshall.csv")

data_sc44 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch4_Roamer.csv")

data_sc45 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch5_Truck.csv")

data_sc46 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch6_Wagon.csv")

# %%
combined_dataframe_sc4 = pd.concat([data_sc41, 
                                    data_sc42, 
                                    data_sc43, 
                                    data_sc44, 
                                    data_sc45, 
                                    data_sc46])
# combined_dataframe_sc2 = pd.concat([data_21, data_22, data_23, data_24, data_25])
print(combined_dataframe_sc4.columns)
# Out:
# Index(['Unnamed: 0', 'bins_0_75', 'bins_1_75', 'bins_2_75', 'bins_3_75',
#        'bins_4_75', 'bins_5_75', 'bins_6_75', 'bins_7_75', 'Entry',
#        'Entry_point', 'Exit', 'Exit_point', 'path_label', 'outcome'],
#       dtype='object')

# %%
cleaned_sc4 = clean_data(combined_dataframe_sc4)
cleaned_sc4
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       1474.0     2001.0        3.0        3.0        2.0        0.0
# 1       3175.0      194.0      222.0     2307.0        4.0        0.0
# 2       1695.0     2840.0        1.0        0.0        1.0        0.0
# 3       1450.0     3775.0      370.0     2886.0        0.0        0.0
# 4       1342.0     1205.0       37.0        1.0        1.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 719     3797.0      306.0      315.0     2173.0        4.0        2.0
# 720     2214.0        5.0        0.0        1.0        1.0        1.0
# 721     4266.0      283.0      394.0     2215.0        7.0        0.0
# 722     2220.0        4.0        0.0        1.0        1.0        0.0
# 723     3730.0      425.0      408.0     2395.0       13.0        0.0
#
#      bins_6_75  bins_7_75  Entry   Exit  outcome
# 0          0.0       24.0   True   True     True
# ...

# %% [markdown]
# # Scenario 5 Batch

# %%
data_sc51 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch1_etk.csv")

data_sc52 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch2_LegranSE.csv")

data_sc53 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch3_Marshall.csv")

data_sc54 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch4_Roamer.csv")

data_sc55 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch5_Truck.csv")

data_sc56 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch6_Wagon.csv")

# %%
combined_dataframe_sc5 = pd.concat([data_sc51, 
                                    data_sc52, 
                                    data_sc53, 
                                    data_sc54, 
                                    data_sc55, 
                                    data_sc56])
# combined_dataframe_sc2 = pd.concat([data_21, data_22, data_23, data_24, data_25])
print(combined_dataframe_sc5.columns)
# Out:
# Index(['Unnamed: 0', 'bins_0_75', 'bins_1_75', 'bins_2_75', 'bins_3_75',
#        'bins_4_75', 'bins_5_75', 'bins_6_75', 'bins_7_75', 'Entry',
#        'Entry_point', 'Exit', 'Exit_point', 'path_label', 'outcome'],
#       dtype='object')

# %%
cleaned_sc5 = clean_data(combined_dataframe_sc5)
cleaned_sc5
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       1167.0      380.0      587.0     1790.0        7.0        0.0
# 1          0.0        0.0       11.0    10873.0        4.0        0.0
# 2       1200.0      394.0      588.0     1859.0        7.0        0.0
# 3          0.0        0.0       10.0    12249.0        6.0        0.0
# 4        927.0      370.0      583.0     1831.0        7.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 369        0.0        3.0      229.0     9461.0        9.0        0.0
# 370     1553.0      128.0      302.0     2248.0       17.0        0.0
# 371        0.0        5.0      250.0     9994.0       11.0        0.0
# 372     1788.0      125.0      301.0     2255.0       16.0        0.0
# 373        0.0        2.0      250.0    10337.0        4.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit  outcome
# 0          0.0        1.0   True  True    False
# ...

# %% [markdown]
# # Additional Batch

# %%
etk_path        = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\etk.csv"
LegranSE_path   = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\LegranSE.csv"
Marshall_path   = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\Marshall.csv"
Roamer_path     = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\Roamer.csv"
Truck_path      = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\Truck.csv"
Wagon_path      = r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\Wagon.csv"

# %%
etk = pd.read_csv(etk_path); legran = pd.read_csv(LegranSE_path) ; marshall = pd.read_csv(Marshall_path) ; Truck = pd.read_csv(Truck_path) ; Wagon = pd.read_csv(Wagon_path)

# %%
combined_additional = pd.concat([etk, legran, marshall, Truck, Wagon])
combined_additional.reset_index(drop=True, inplace=True)
combined_additional
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0        0.0        1.0      181.0     1647.0        6.0
# 1             1        0.0        2.0      191.0     4951.0       55.0
# 2             2        0.0        1.0       57.0     1983.0       13.0
# 3             3        0.0        6.0      389.0     2732.0       16.0
# 4             4        0.0        6.0      964.0     1725.0        4.0
# ..          ...        ...        ...        ...        ...        ...
# 329          65        0.0        5.0       62.0    10976.0       18.0
# 330          66        0.0      155.0     1047.0     1633.0        1.0
# 331          67        0.0        0.0       22.0    12552.0       17.0
# 332          68        0.0        1.0       50.0     5435.0        2.0
# 333          69        0.0        3.0       19.0     8303.0       11.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry  Entry_point   Exit  Exit_point  \
# ...

# %%
combined_additional["scenario"] = "additional_sc5"
combined_additional
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0        0.0        1.0      181.0     1647.0        6.0
# 1             1        0.0        2.0      191.0     4951.0       55.0
# 2             2        0.0        1.0       57.0     1983.0       13.0
# 3             3        0.0        6.0      389.0     2732.0       16.0
# 4             4        0.0        6.0      964.0     1725.0        4.0
# ..          ...        ...        ...        ...        ...        ...
# 329          65        0.0        5.0       62.0    10976.0       18.0
# 330          66        0.0      155.0     1047.0     1633.0        1.0
# 331          67        0.0        0.0       22.0    12552.0       17.0
# 332          68        0.0        1.0       50.0     5435.0        2.0
# 333          69        0.0        3.0       19.0     8303.0       11.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry  Entry_point   Exit  Exit_point  \
# ...

# %%
read_sc4 = pd.read_csv(r"D:\additional_data\additional_cases\additional_sc4.csv")
read_sc4
# Out:
#     bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       191.0        3.0        0.0        2.0        4.0        0.0
# 1        20.0       46.0       87.0     2044.0        3.0        0.0
# 2       376.0        6.0        0.0        1.0        2.0        0.0
# 3        28.0      207.0       98.0     2278.0        3.0        0.0
# 4        98.0        3.0        0.0        1.0        2.0        0.0
# 5        19.0      164.0      106.0     2352.0        3.0        1.0
# 6       239.0        4.0        0.0        2.0        3.0        1.0
# 7        47.0      235.0       93.0     2426.0        3.0        0.0
# 8       259.0        2.0        1.0        1.0        3.0        1.0
# 9         7.0      418.0      109.0     2468.0        3.0        1.0
# 10      111.0       94.0        1.0        0.0        0.0        0.0
# 11        0.0      452.0      106.0     2516.0        3.0        0.0
# 12       31.0     1697.0        3.0        1.0        1.0        0.0
# ...

# %%
read_sc4["scenario"] = "additional_sc4"
read_sc4
# Out:
#     bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       191.0        3.0        0.0        2.0        4.0        0.0
# 1        20.0       46.0       87.0     2044.0        3.0        0.0
# 2       376.0        6.0        0.0        1.0        2.0        0.0
# 3        28.0      207.0       98.0     2278.0        3.0        0.0
# 4        98.0        3.0        0.0        1.0        2.0        0.0
# 5        19.0      164.0      106.0     2352.0        3.0        1.0
# 6       239.0        4.0        0.0        2.0        3.0        1.0
# 7        47.0      235.0       93.0     2426.0        3.0        0.0
# 8       259.0        2.0        1.0        1.0        3.0        1.0
# 9         7.0      418.0      109.0     2468.0        3.0        1.0
# 10      111.0       94.0        1.0        0.0        0.0        0.0
# 11        0.0      452.0      106.0     2516.0        3.0        0.0
# 12       31.0     1697.0        3.0        1.0        1.0        0.0
# ...

# %%
additional_sc5 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\cleaned_sc5.csv")
additional_sc4 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\cleaned_sc4.csv")

# %%
combined_all = pd.concat([additional_sc5, additional_sc4])
combined_all.reset_index(drop=True, inplace=True)
combined_all
# Out:
#      Unnamed: 0.1  Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  \
# 0             0.0           0        0.0        1.0      181.0     1647.0
# 1             1.0           1        0.0        2.0      191.0     4951.0
# 2             2.0           2        0.0        1.0       57.0     1983.0
# 3             3.0           3        0.0        6.0      389.0     2732.0
# 4             4.0           4        0.0        6.0      964.0     1725.0
# ..            ...         ...        ...        ...        ...        ...
# 389           NaN          55       12.0      117.0       98.0     2255.0
# 390           NaN          56      178.0        4.0        0.0        2.0
# 391           NaN          57       11.0      161.0       98.0     2340.0
# 392           NaN          58      181.0        2.0        0.0        2.0
# 393           NaN          59       28.0      264.0       93.0     2346.0
#
#      bins_4_75  bins_5_75  bins_6_75  bins_7_75  Entry  Entry_point   Exit  \
# ...

# %%
combined_all.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], inplace=True)
combined_all
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0          0.0        1.0      181.0     1647.0        6.0        0.0
# 1          0.0        2.0      191.0     4951.0       55.0        2.0
# 2          0.0        1.0       57.0     1983.0       13.0        0.0
# 3          0.0        6.0      389.0     2732.0       16.0        1.0
# 4          0.0        6.0      964.0     1725.0        4.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 389       12.0      117.0       98.0     2255.0        3.0        1.0
# 390      178.0        4.0        0.0        2.0        3.0        0.0
# 391       11.0      161.0       98.0     2340.0        3.0        1.0
# 392      181.0        2.0        0.0        2.0        2.0        0.0
# 393       28.0      264.0       93.0     2346.0        3.0        1.0
#
#      bins_6_75  bins_7_75  Entry  Entry_point   Exit  Exit_point path_label  \
# ...

# %% [markdown]
# # Add scenario description

# %% [markdown]
# ### Scenario 1

# %%
data_sc11 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_1_wagon.csv")

data_sc12 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_2_truck.csv")

data_sc13 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_3_Roamer.csv")

data_sc14 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_4_Marshall.csv")

data_sc15 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_5_LegranSE.csv")

data_sc16 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario1\Batch_6_etk.csv")

# %%
data_scenario1 = clean_data(data_sc11, data_sc12, data_sc13, data_sc14, data_sc15, data_sc15)
data_scenario1
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0      325.0       30.0        2.0        3.0        2.0
# 1             1        0.0        1.0       97.0     2974.0       20.0
# 2             2      386.0       30.0        2.0        2.0        2.0
# 3             3        0.0        2.0       91.0     2957.0       16.0
# 4             4      219.0      182.0        2.0        3.0        2.0
# ..          ...        ...        ...        ...        ...        ...
# 778         125       86.0      682.0        8.0       12.0        3.0
# 779         126        0.0        0.0       41.0    13184.0       19.0
# 780         127      142.0      725.0        5.0       10.0        3.0
# 781         128      133.0      134.0        3.0        6.0        3.0
# 782         129        0.0        0.0       59.0    12321.0        9.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry   Exit path_label  outcome
# ...

# %%
data_scenario1 = to_numBoolean(data_scenario1, ["Entry", "Exit"])
data_scenario1.drop(columns=["Unnamed: 0"], inplace=True)
data_scenario1
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0        325.0       30.0        2.0        3.0        2.0        0.0
# 1          0.0        1.0       97.0     2974.0       20.0        1.0
# 2        386.0       30.0        2.0        2.0        2.0        0.0
# 3          0.0        2.0       91.0     2957.0       16.0        1.0
# 4        219.0      182.0        2.0        3.0        2.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 778       86.0      682.0        8.0       12.0        3.0        0.0
# 779        0.0        0.0       41.0    13184.0       19.0        0.0
# 780      142.0      725.0        5.0       10.0        3.0        1.0
# 781      133.0      134.0        3.0        6.0        3.0        1.0
# 782        0.0        0.0       59.0    12321.0        9.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome
# 0          1.0       20.0      1     1      40-30     True
# ...

# %%
data_scenario1 = to_numBoolean(data_scenario1, ["outcome"])
data_scenario1["scenario"] = "org_sc1"
data_scenario1
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0        325.0       30.0        2.0        3.0        2.0        0.0
# 1          0.0        1.0       97.0     2974.0       20.0        1.0
# 2        386.0       30.0        2.0        2.0        2.0        0.0
# 3          0.0        2.0       91.0     2957.0       16.0        1.0
# 4        219.0      182.0        2.0        3.0        2.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 778       86.0      682.0        8.0       12.0        3.0        0.0
# 779        0.0        0.0       41.0    13184.0       19.0        0.0
# 780      142.0      725.0        5.0       10.0        3.0        1.0
# 781      133.0      134.0        3.0        6.0        3.0        1.0
# 782        0.0        0.0       59.0    12321.0        9.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome scenario
# ...

# %% [markdown]
# ### Scenario 2

# %%
data_sc21 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch1_etk.csv")

data_sc22 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch2_legran.csv")

data_sc23 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch3_Marshall.csv")

data_sc24 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch4_Roamer.csv")

data_sc25 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch5_Wagon.csv")

data_sc26 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario2\Batch6_Trucks.csv")

# %%
data_scenario2 = clean_data(data_sc21, data_sc22, data_sc23, data_sc24, data_sc25, data_sc26)
data_scenario2
# Out:
#      Unnamed: 0  index  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0    0.0       14.0      148.0        9.0       12.0       25.0
# 1             1    1.0        1.0        4.0       26.0      374.0    16823.0
# 2             2    2.0       40.0      154.0       13.0       14.0       22.0
# 3             3    3.0       63.0      133.0       12.0       20.0       27.0
# 4             4    4.0       34.0      141.0        9.0       50.0       47.0
# ..          ...    ...        ...        ...        ...        ...        ...
# 667         107    NaN        0.0        3.0        0.0     8457.0    11156.0
# 668         108    NaN      198.0      221.0        5.0        4.0        5.0
# 669         109    NaN        0.0        0.0        0.0     8461.0    11645.0
# 670         110    NaN      154.0      254.0        5.0        4.0        5.0
# 671         111    NaN        0.0        1.0        0.0     8313.0    11442.0
#
# ...

# %%
data_scenario2 = to_numBoolean(data_scenario2, ["Entry", "Exit", "outcome"])
data_scenario2.drop(columns=["Unnamed: 0", "index"], inplace=True)
data_scenario2["scenario"] = "org_sc2"
data_scenario2
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0         14.0      148.0        9.0       12.0       25.0        4.0
# 1          1.0        4.0       26.0      374.0    16823.0       25.0
# 2         40.0      154.0       13.0       14.0       22.0        4.0
# 3         63.0      133.0       12.0       20.0       27.0        5.0
# 4         34.0      141.0        9.0       50.0       47.0       13.0
# ..         ...        ...        ...        ...        ...        ...
# 667        0.0        3.0        0.0     8457.0    11156.0        0.0
# 668      198.0      221.0        5.0        4.0        5.0        2.0
# 669        0.0        0.0        0.0     8461.0    11645.0        0.0
# 670      154.0      254.0        5.0        4.0        5.0        2.0
# 671        0.0        1.0        0.0     8313.0    11442.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome scenario
# ...

# %%
data_scenario2
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0        325.0       30.0        2.0        3.0        2.0        0.0
# 1          0.0        1.0       97.0     2974.0       20.0        1.0
# 2        386.0       30.0        2.0        2.0        2.0        0.0
# 3          0.0        2.0       91.0     2957.0       16.0        1.0
# 4        219.0      182.0        2.0        3.0        2.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 778       86.0      682.0        8.0       12.0        3.0        0.0
# 779        0.0        0.0       41.0    13184.0       19.0        0.0
# 780      142.0      725.0        5.0       10.0        3.0        1.0
# 781      133.0      134.0        3.0        6.0        3.0        1.0
# 782        0.0        0.0       59.0    12321.0        9.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit  outcome scenario
# 0          1.0       20.0      1     1        1  org_sc1
# ...

# %% [markdown]
# ### Scenario 3

# %%
data_sc31 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch1_etk.csv")

data_sc32 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch2_LegranSE.csv")

data_sc33 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch3_Marshall.csv")

data_sc34 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch4_Roamer.csv")

data_sc35 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch5_Truck.csv")

data_sc36 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario3\Batch6_Wagon.csv")

# %%
data_scenario3 = clean_data(data_sc31, data_sc32, data_sc33, data_sc34, data_sc35, data_sc36)
data_scenario3
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0        5.0       80.0      100.0     2851.0       60.0
# 1             1      691.0       48.0       10.0       14.0       10.0
# 2             2        4.0        8.0       97.0     3191.0      126.0
# 3             3      856.0       42.0       12.0        8.0        8.0
# 4             4       15.0        8.0       51.0     3588.0      144.0
# ..          ...        ...        ...        ...        ...        ...
# 779         126     1574.0        7.0        2.0        5.0        3.0
# 780         127        1.0        2.0       74.0     7467.0      101.0
# 781         128     1303.0        8.0        3.0        4.0        3.0
# 782         129        1.0        3.0       77.0     7391.0       87.0
# 783         130     1639.0       10.0        2.0        4.0        2.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry   Exit path_label  outcome
# ...

# %%
data_scenario3 = to_numBoolean(data_scenario3, ["Entry", "Exit", "outcome"])
data_scenario3.drop(columns=["Unnamed: 0"], inplace=True)
data_scenario3["scenario"] = "org_sc3"
data_scenario3
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0          5.0       80.0      100.0     2851.0       60.0        4.0
# 1        691.0       48.0       10.0       14.0       10.0        2.0
# 2          4.0        8.0       97.0     3191.0      126.0        6.0
# 3        856.0       42.0       12.0        8.0        8.0        1.0
# 4         15.0        8.0       51.0     3588.0      144.0        4.0
# ..         ...        ...        ...        ...        ...        ...
# 779     1574.0        7.0        2.0        5.0        3.0        0.0
# 780        1.0        2.0       74.0     7467.0      101.0        2.0
# 781     1303.0        8.0        3.0        4.0        3.0        1.0
# 782        1.0        3.0       77.0     7391.0       87.0        1.0
# 783     1639.0       10.0        2.0        4.0        2.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome scenario
# ...

# %% [markdown]
# ### Scenario 4

# %%
data_sc41 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch1_etk.csv")

data_sc42 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch2_LegranSE.csv")

data_sc43 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch3_Marshall.csv")

data_sc44 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch4_Roamer.csv")

data_sc45 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch5_Truck.csv")

data_sc46 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario4\Batch6_Wagon.csv")

# %%
data_scenario4 = clean_data(data_sc41, data_sc42, data_sc43, data_sc44, data_sc45, data_sc46)
data_scenario4
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0     1474.0     2001.0        3.0        3.0        2.0
# 1             1     3175.0      194.0      222.0     2307.0        4.0
# 2             2     1695.0     2840.0        1.0        0.0        1.0
# 3             3     1450.0     3775.0      370.0     2886.0        0.0
# 4             4     1342.0     1205.0       37.0        1.0        1.0
# ..          ...        ...        ...        ...        ...        ...
# 719         115     3797.0      306.0      315.0     2173.0        4.0
# 720         116     2214.0        5.0        0.0        1.0        1.0
# 721         117     4266.0      283.0      394.0     2215.0        7.0
# 722         118     2220.0        4.0        0.0        1.0        1.0
# 723         119     3730.0      425.0      408.0     2395.0       13.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry   Exit path_label  outcome
# ...

# %%
data_scenario4 = to_numBoolean(data_scenario4, ["Entry", "Exit", "outcome"])
data_scenario4.drop(columns=["Unnamed: 0"], inplace=True)
data_scenario4["scenario"] = "org_sc4"
data_scenario4
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       1474.0     2001.0        3.0        3.0        2.0        0.0
# 1       3175.0      194.0      222.0     2307.0        4.0        0.0
# 2       1695.0     2840.0        1.0        0.0        1.0        0.0
# 3       1450.0     3775.0      370.0     2886.0        0.0        0.0
# 4       1342.0     1205.0       37.0        1.0        1.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 719     3797.0      306.0      315.0     2173.0        4.0        2.0
# 720     2214.0        5.0        0.0        1.0        1.0        1.0
# 721     4266.0      283.0      394.0     2215.0        7.0        0.0
# 722     2220.0        4.0        0.0        1.0        1.0        0.0
# 723     3730.0      425.0      408.0     2395.0       13.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome scenario
# ...

# %% [markdown]
# ### Scenario 5

# %%
data_sc51 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch1_etk.csv")

data_sc52 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch2_LegranSE.csv")

data_sc53 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch3_Marshall.csv")

data_sc54 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch4_Roamer.csv")

data_sc55 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch5_Truck.csv")

data_sc56 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\scenario5\Batch6_Wagon.csv")

# %%
data_scenario5 = clean_data(data_sc51, data_sc52, data_sc53, data_sc54, data_sc55, data_sc56)
data_scenario5
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0     1167.0      380.0      587.0     1790.0        7.0
# 1             1        0.0        0.0       11.0    10873.0        4.0
# 2             2     1200.0      394.0      588.0     1859.0        7.0
# 3             3        0.0        0.0       10.0    12249.0        6.0
# 4             4      927.0      370.0      583.0     1831.0        7.0
# ..          ...        ...        ...        ...        ...        ...
# 369          55        0.0        3.0      229.0     9461.0        9.0
# 370          56     1553.0      128.0      302.0     2248.0       17.0
# 371          57        0.0        5.0      250.0     9994.0       11.0
# 372          58     1788.0      125.0      301.0     2255.0       16.0
# 373          59        0.0        2.0      250.0    10337.0        4.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry  Exit path_label  outcome
# ...

# %%
data_scenario5 = to_numBoolean(data_scenario5, ["Entry", "Exit", "outcome"])
data_scenario5.drop(columns=["Unnamed: 0"], inplace=True)
data_scenario5["scenario"] = "org_sc5"
data_scenario5
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0       1167.0      380.0      587.0     1790.0        7.0        0.0
# 1          0.0        0.0       11.0    10873.0        4.0        0.0
# 2       1200.0      394.0      588.0     1859.0        7.0        0.0
# 3          0.0        0.0       10.0    12249.0        6.0        0.0
# 4        927.0      370.0      583.0     1831.0        7.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 369        0.0        3.0      229.0     9461.0        9.0        0.0
# 370     1553.0      128.0      302.0     2248.0       17.0        0.0
# 371        0.0        5.0      250.0     9994.0       11.0        0.0
# 372     1788.0      125.0      301.0     2255.0       16.0        0.0
# 373        0.0        2.0      250.0    10337.0        4.0        0.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome scenario
# ...

# %% [markdown]
# ### Additional cases

# %%
addition_sc5sc4 = pd.read_csv(r"E:\01_Programming\Py\MasterThesis_CUDA\dataset\additional_data\batch_dir\cleaned_additional.csv")
addition_sc5sc4
# Out:
#      Unnamed: 0  bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  \
# 0             0        0.0        1.0      181.0     1647.0        6.0
# 1             1        0.0        2.0      191.0     4951.0       55.0
# 2             2        0.0        1.0       57.0     1983.0       13.0
# 3             3        0.0        6.0      389.0     2732.0       16.0
# 4             4        0.0        6.0      964.0     1725.0        4.0
# ..          ...        ...        ...        ...        ...        ...
# 389         389       12.0      117.0       98.0     2255.0        3.0
# 390         390      178.0        4.0        0.0        2.0        3.0
# 391         391       11.0      161.0       98.0     2340.0        3.0
# 392         392      181.0        2.0        0.0        2.0        2.0
# 393         393       28.0      264.0       93.0     2346.0        3.0
#
#      bins_5_75  bins_6_75  bins_7_75  Entry  Entry_point   Exit  Exit_point  \
# ...

# %%
addition_sc5sc4.drop(columns=["Unnamed: 0", "Exit_point", "Entry_point"], inplace=True)
addition_sc5sc4 = to_numBoolean(addition_sc5sc4, ["Entry", "Exit", "outcome"])
addition_sc5sc4
# Out:
#      bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0          0.0        1.0      181.0     1647.0        6.0        0.0
# 1          0.0        2.0      191.0     4951.0       55.0        2.0
# 2          0.0        1.0       57.0     1983.0       13.0        0.0
# 3          0.0        6.0      389.0     2732.0       16.0        1.0
# 4          0.0        6.0      964.0     1725.0        4.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 389       12.0      117.0       98.0     2255.0        3.0        1.0
# 390      178.0        4.0        0.0        2.0        3.0        0.0
# 391       11.0      161.0       98.0     2340.0        3.0        1.0
# 392      181.0        2.0        0.0        2.0        2.0        0.0
# 393       28.0      264.0       93.0     2346.0        3.0        1.0
#
#      bins_6_75  bins_7_75  Entry  Exit path_label  outcome        scenario
# ...

# %% [markdown]
# # Create MasterFile

# %%
MasterFile = pd.concat([
    data_scenario1, 
    data_scenario2, 
    data_scenario3, 
    data_scenario4, 
    data_scenario5,
    addition_sc5sc4
])
MasterFile.reset_index(drop=True, inplace=True)
MasterFile
# Out:
#       bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0         325.0       30.0        2.0        3.0        2.0        0.0
# 1           0.0        1.0       97.0     2974.0       20.0        1.0
# 2         386.0       30.0        2.0        2.0        2.0        0.0
# 3           0.0        2.0       91.0     2957.0       16.0        1.0
# 4         219.0      182.0        2.0        3.0        2.0        0.0
# ...         ...        ...        ...        ...        ...        ...
# 3726       12.0      117.0       98.0     2255.0        3.0        1.0
# 3727      178.0        4.0        0.0        2.0        3.0        0.0
# 3728       11.0      161.0       98.0     2340.0        3.0        1.0
# 3729      181.0        2.0        0.0        2.0        2.0        0.0
# 3730       28.0      264.0       93.0     2346.0        3.0        1.0
#
#       bins_6_75  bins_7_75  Entry  Exit path_label  outcome        scenario
# ...

# %%
MasterFile.drop(columns=["Unnamed: 0"], inplace=True)
MasterFile
# Out:
#       bins_0_75  bins_1_75  bins_2_75  bins_3_75  bins_4_75  bins_5_75  \
# 0         325.0       30.0        2.0        3.0        2.0        0.0
# 1           0.0        1.0       97.0     2974.0       20.0        1.0
# 2         386.0       30.0        2.0        2.0        2.0        0.0
# 3           0.0        2.0       91.0     2957.0       16.0        1.0
# 4         219.0      182.0        2.0        3.0        2.0        0.0
# ...         ...        ...        ...        ...        ...        ...
# 3358       12.0      117.0       98.0     2255.0        3.0        1.0
# 3359      178.0        4.0        0.0        2.0        3.0        0.0
# 3360       11.0      161.0       98.0     2340.0        3.0        1.0
# 3361      181.0        2.0        0.0        2.0        2.0        0.0
# 3362       28.0      264.0       93.0     2346.0        3.0        1.0
#
#       bins_6_75  bins_7_75  Entry  Exit  outcome        scenario  Entry_point  \
# ...
